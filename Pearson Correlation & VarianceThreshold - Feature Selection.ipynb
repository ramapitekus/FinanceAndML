# %%
import pandas as pd
import seaborn as sns
import os
from os import path
import matplotlib.pyplot as plt

# %%
#Feature Selection: Variance Threshold - omit all columns with variance <= 0.1 (or 0.01, 0.05 etc.)

# %%
import pandas as pd
from sklearn.feature_selection import VarianceThreshold

# %%
df = pd.read_csv (r'C:\Users\shara\Documents\UZH\Master\HS21\Finance & Machine Learning\Project\cleaned\cleaned_indicators-01-04-2013-31-12-2020.csv')

# %%
df.shape
# Out:
# (2459, 439)

# %%
df.head()
# Out:
#    Index        Date  bitcoin-marketcap_raw  bitcoin-price_raw  \
# 0      0  2013/04/01             1039517192             94.715
# 1      1  2013/04/02             1183101461            107.749
# 2      2  2013/04/03             1318189886            120.003
# 3      3  2013/04/04             1357824968            123.562
# 4      4  2013/04/05             1414392012            128.664
#
#    bitcoin-transactions_raw  bitcoin-sentinusd_raw  \
# 0                     52572              127826531
# 1                     63095              257306533
# 2                     63766              252194497
# 3                     66738              226470029
# 4                     61215              227376421
#
#    bitcoin-transactionvalue_raw  bitcoin-mediantransactionvalue_raw  \
# 0                        2592.0                              64.987
# 1                        4400.0                              94.955
# 2                        4478.0                             102.533
# 3                        4249.0                             123.314
# 4                        4348.0                             125.183
#
#    bitcoin-transactionfees_raw  bitcoin-median_transaction_fee_raw  ...  \
# 0                       0.0777                              0.0474  ...
# 1                       0.1050                              0.0539  ...
# 2                       0.1330                              0.0600  ...
# 3                       0.1410                              0.0618  ...
# 4                       0.1200                              0.0643  ...
#
#    fee_to_reward-btc-rsi-3  fee_to_reward-btc-rsi-7  fee_to_reward-btc-rsi-14  \
# 0                   22.288                   40.508                    45.841
# 1                   60.030                   53.497                    51.379
# 2                   71.432                   59.191                    54.145
# 3                   81.948                   65.836                    57.676
# 4                   45.267                   51.483                    51.419
#
#    fee_to_reward-btc-rsi-30  fee_to_reward-btc-rsi-90  \
# 0                    48.122                    49.775
# 1                    50.663                    50.838
# 2                    51.995                    51.407
# 3                    53.754                    52.170
# 4                    50.922                    50.982
#
#    fee_to_reward-btc-roc-3  fee_to_reward-btc-roc-7  fee_to_reward-btc-roc-14  \
# 0                  -37.176                  -28.973                     9.279
# 1                   -8.601                   12.433                    11.040
# 2                   48.108                  -11.535                   127.579
# 3                  124.559                   47.185                   110.845
# 4                    7.007                    3.735                    21.942
#
#    fee_to_reward-btc-roc-30  fee_to_reward-btc-roc-90
# 0                   -37.847                    38.401
# 1                    20.765                    60.341
# 2                    30.544                    72.575
# 3                    33.318                    94.811
# 4                   -63.371                    61.872
#
# [5 rows x 439 columns]

# %%
#Separate dependent variable ("bitcoin-price_raw") from independent variables

# %%
X=df.drop(labels=['bitcoin-price_raw','Date'], axis=1)
y=df['bitcoin-price_raw']

# %%
#separate dataset into train and test (70/30 split) to avoid overfitting when features are removed

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df.drop(labels=['bitcoin-price_raw','Date'], axis=1),
    df['bitcoin-price_raw'],
    test_size=0.3,
    random_state=0)

# %%
X_train.shape, X_test.shape
# Out:
# ((1721, 437), (738, 437))

# %%
#Continue with X_train only - perform feature selection on X_train, then later omit the undesirable features from X_test manually.

# %%
X_train.head()
# Out:
#       Index  bitcoin-marketcap_raw  bitcoin-transactions_raw  \
# 2005   2005           112867119320                    248543
# 516     516             6587252252                     61032
# 758     758             3202952244                    117133
# 1806   1806           159831136581                    188233
# 1979   1979           122656017234                    213180
#
#       bitcoin-sentinusd_raw  bitcoin-transactionvalue_raw  \
# 2005             4057583228                       23772.0
# 516               232611687                        4962.0
# 758               260418894                        2484.0
# 1806             6382912960                       51118.0
# 1979             4362467708                       29365.0
#
#       bitcoin-mediantransactionvalue_raw  bitcoin-transactionfees_raw  \
# 2005                             297.380                       0.6210
# 516                               79.849                       0.0752
# 758                               66.086                       0.0324
# 1806                             565.518                       1.6810
# 1979                             295.232                       0.6410
#
#       bitcoin-median_transaction_fee_raw  bitcoin-confirmationtime_raw  \
# 2005                              0.1990                        10.070
# 516                               0.0503                         7.912
# 758                               0.0225                        11.339
# 1806                              0.2140                         8.944
# 1979                              0.1460                         9.536
#
#       bitcoin-size_raw  ...  fee_to_reward-btc-rsi-3  fee_to_reward-btc-rsi-7  \
# 2005            663091  ...                   79.149                   60.424
# 516             186250  ...                   27.777                   41.830
# 758             494971  ...                   45.927                   48.466
# 1806            834110  ...                   28.814                   39.431
# 1979            609255  ...                   28.766                   42.340
#
#       fee_to_reward-btc-rsi-14  fee_to_reward-btc-rsi-30  \
# 2005                    53.725                    50.945
# 516                     45.833                    47.789
# 758                     49.762                    50.447
# 1806                    39.428                    40.634
# 1979                    46.964                    48.582
#
#       fee_to_reward-btc-rsi-90  fee_to_reward-btc-roc-3  \
# 2005                    48.678                   57.090
# 516                     49.004                  -26.398
# 758                     50.635                   42.120
# 1806                    46.456                  -12.682
# 1979                    48.139                  -24.951
#
#       fee_to_reward-btc-roc-7  fee_to_reward-btc-roc-14  \
# 2005                   38.967                    20.329
# 516                    -5.676                   -39.119
# 758                    27.159                     4.727
# 1806                  -29.940                   -35.940
# 1979                  -18.267                    23.469
#
#       fee_to_reward-btc-roc-30  fee_to_reward-btc-roc-90
# 2005                   -43.455                    -8.780
# 516                    -31.226                   -18.270
# 758                     21.940                    77.656
# 1806                   -65.432                   -92.431
# 1979                   -22.549                    35.083
#
# [5 rows x 437 columns]

# %%
#We need to normalize data so that variance threshold is comparable across all features

# %%
X_norm = (X_train-X_train.min())/(X_train.max()-X_train.min())
X_norm.head()
# Out:
#          Index  bitcoin-marketcap_raw  bitcoin-transactions_raw  \
# 2005  0.816036               0.346159                  0.474426
# 516   0.210012               0.018020                  0.067049
# 758   0.308506               0.007571                  0.188931
# 1806  0.735043               0.491160                  0.343399
# 1979  0.805454               0.376382                  0.397598
#
#       bitcoin-sentinusd_raw  bitcoin-transactionvalue_raw  \
# 2005               0.086765                      0.028211
# 516                0.004345                      0.005021
# 758                0.004944                      0.001966
# 1806               0.136870                      0.061924
# 1979               0.093334                      0.035106
#
#       bitcoin-mediantransactionvalue_raw  bitcoin-transactionfees_raw  \
# 2005                            0.053862                     0.010792
# 516                             0.012680                     0.000846
# 758                             0.010074                     0.000066
# 1806                            0.104625                     0.030110
# 1979                            0.053456                     0.011157
#
#       bitcoin-median_transaction_fee_raw  bitcoin-confirmationtime_raw  \
# 2005                            0.005332                      0.363666
# 516                             0.000968                      0.190499
# 758                             0.000153                      0.465495
# 1806                            0.005772                      0.273311
# 1979                            0.003777                      0.320815
#
#       bitcoin-size_raw  ...  fee_to_reward-btc-rsi-3  fee_to_reward-btc-rsi-7  \
# 2005          0.636935  ...                 0.794732                 0.587935
# 516           0.119551  ...                 0.265919                 0.359446
# 758           0.454521  ...                 0.452752                 0.440991
# 1806          0.822494  ...                 0.276594                 0.329966
# 1979          0.578522  ...                 0.276100                 0.365713
#
#       fee_to_reward-btc-rsi-14  fee_to_reward-btc-rsi-30  \
# 2005                  0.441241                  0.305994
# 516                   0.311673                  0.228333
# 758                   0.376178                  0.293740
# 1806                  0.206518                  0.052266
# 1979                  0.330241                  0.247847
#
#       fee_to_reward-btc-rsi-90  fee_to_reward-btc-roc-3  \
# 2005                  0.112828                 0.087388
# 516                   0.128276                 0.038292
# 758                   0.205563                 0.078584
# 1806                  0.007534                 0.046358
# 1979                  0.087286                 0.039143
#
#       fee_to_reward-btc-roc-7  fee_to_reward-btc-roc-14  \
# 2005                 0.109891                  0.114378
# 516                  0.072119                  0.053780
# 758                  0.099901                  0.098474
# 1806                 0.051590                  0.057020
# 1979                 0.061466                  0.117579
#
#       fee_to_reward-btc-roc-30  fee_to_reward-btc-roc-90
# 2005                  0.050198                  0.095958
# 516                   0.063656                  0.085576
# 758                   0.122161                  0.190520
# 1806                  0.026014                  0.004444
# 1979                  0.073204                  0.143945
#
# [5 rows x 437 columns]

# %%
#
#VARIANCE THRESHOLD
#

# %%
#We might have to discuss what the appropriate threshold should be. Is a variance threshold of 0.01 reasonable?

# %%
var_thres=VarianceThreshold(threshold=0.01)
var_thres.fit(X_norm)
# Out:
# VarianceThreshold(threshold=0.01)

# %%
var_thres.get_support()
# Out:
# array([ True,  True,  True,  True, False, False, False, False, False,
#         True,  True,  True,  True, False,  True,  True, False,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True, False,
#        False,  True,  True,  True, False,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False,  True,  True,  True,  True, False,  True,  True,
#         True,  True,  True,  True,  True,  True,  True, False, False,
#         True,  True,  True, False,  True,  True,  True,  True, False,
#         True,  True,  True,  True, False,  True,  True,  True,  True,
#        False, False, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#        False,  True,  True,  True,  True, False, False, False,  True,
#         True, False, False, False,  True,  True,  True,  True,  True,
#        False, False, False, False, False, False, False, False, False,
#         True,  True,  True, False, False,  True,  True,  True, False,
#        False,  True,  True,  True, False, False, False,  True,  True,
#        False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False, False, False,  True, False, False, False,  True,
#         True,  True, False, False,  True,  True,  True, False, False,
#        False,  True,  True, False, False,  True,  True, False, False,
#         True,  True,  True,  True,  True,  True,  True,  True, False,
#        False, False, False,  True, False,  True,  True,  True,  True,
#        False,  True,  True,  True,  True, False,  True,  True,  True,
#         True, False,  True,  True,  True,  True, False, False,  True,
#         True,  True, False,  True,  True,  True,  True,  True,  True,
#         True, False, False, False, False, False, False, False,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True, False,  True,  True,  True,
#         True, False, False, False, False,  True, False,  True,  True,
#         True,  True,  True,  True,  True,  True,  True, False, False,
#        False, False, False, False,  True,  True,  True,  True, False,
#        False,  True,  True,  True, False, False,  True,  True,  True,
#        False, False, False,  True,  True, False, False, False,  True,
#         True, False, False, False,  True,  True,  True,  True,  True,
#        False, False, False, False, False, False, False, False, False,
#         True,  True,  True, False,  True,  True,  True,  True, False,
#         True,  True,  True,  True, False,  True,  True,  True,  True,
#        False, False, False,  True,  True, False,  True,  True,  True,
#         True,  True,  True,  True,  True,  True, False, False, False,
#        False, False,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True, False,
#         True,  True,  True,  True, False, False,  True,  True, False,
#         True,  True,  True,  True,  True,  True,  True, False, False,
#        False, False, False, False,  True])

# %%
#How many features don't have low variance? (Number of TRUEs)

# %%
len(X_norm.columns[var_thres.get_support()])
# Out:
# 303

# %%
#How many features have low variance?

# %%
low_variance = [column for column in X_norm.columns
                    if column not in X_norm.columns[var_thres.get_support()]]

# %%
print(len(low_variance))
# Out:
# 134

# %%
#Which are the features with low variance?

# %%
for column in low_variance:
    print(column)
# Out:
# bitcoin-transactionvalue_raw
# bitcoin-mediantransactionvalue_raw
# bitcoin-transactionfees_raw
# bitcoin-median_transaction_fee_raw
# bitcoin-confirmationtime_raw
# bitcoin-mining_profitability_raw
# google_trends-btc_raw
# difficulty-btc-var-3
# difficulty-btc-var-7
# difficulty-btc-trx-3
# hashrate-btc-var-3
# hashrate-btc-trx-3
# hashrate-btc-roc-3
# hashrate-btc-roc-7
# mining_profitability-btc-sma-3
# mining_profitability-btc-ema-3
# mining_profitability-btc-wma-3
# mining_profitability-btc-std-3
# mining_profitability-btc-std-7
# mining_profitability-btc-std-14
# mining_profitability-btc-roc-90
# sentinusd-btc-std-3
# sentinusd-btc-var-3
# sentinusd-btc-var-7
# sentinusd-btc-var-14
# sentinusd-btc-trx-3
# sentinusd-btc-trx-7
# sentinusd-btc-trx-14
# sentinusd-btc-rsi-30
# sentinusd-btc-rsi-90
# sentinusd-btc-roc-3
# sentinusd-btc-roc-7
# sentinusd-btc-roc-14
# sentinusd-btc-roc-30
# sentinusd-btc-roc-90
# transactionfees-btc-sma-3
# transactionfees-btc-sma-7
# transactionfees-btc-ema-3
# transactionfees-btc-ema-7
# transactionfees-btc-wma-3
# transactionfees-btc-wma-7
# transactionfees-btc-std-3
# transactionfees-btc-std-7
# transactionfees-btc-std-14
# transactionfees-btc-trx-3
# transactionfees-btc-roc-3
# transactionfees-btc-roc-7
# transactionfees-btc-roc-14
# transactionfees-btc-roc-90
# median_transaction_fee-btc-sma-3
# median_transaction_fee-btc-sma-7
# median_transaction_fee-btc-ema-3
# median_transaction_fee-btc-ema-7
# median_transaction_fee-btc-wma-3
# median_transaction_fee-btc-wma-7
# median_transaction_fee-btc-wma-14
# median_transaction_fee-btc-std-7
# median_transaction_fee-btc-std-14
# median_transaction_fee-btc-trx-3
# median_transaction_fee-btc-trx-7
# median_transaction_fee-btc-roc-3
# median_transaction_fee-btc-roc-7
# median_transaction_fee-btc-roc-14
# median_transaction_fee-btc-roc-30
# confirmationtime-btc-sma-3
# confirmationtime-btc-ema-3
# confirmationtime-btc-wma-3
# confirmationtime-btc-std-3
# confirmationtime-btc-var-3
# confirmationtime-btc-var-7
# confirmationtime-btc-trx-3
# confirmationtime-btc-rsi-30
# confirmationtime-btc-rsi-90
# confirmationtime-btc-roc-3
# confirmationtime-btc-roc-7
# confirmationtime-btc-roc-14
# confirmationtime-btc-roc-30
# confirmationtime-btc-roc-90
# marketcap-btc-std-3
# marketcap-btc-var-3
# marketcap-btc-var-7
# marketcap-btc-var-14
# marketcap-btc-var-30
# marketcap-btc-trx-3
# marketcap-btc-roc-3
# marketcap-btc-roc-7
# marketcap-btc-roc-14
# marketcap-btc-roc-30
# marketcap-btc-roc-90
# transactionvalue-btc-sma-3
# transactionvalue-btc-ema-3
# transactionvalue-btc-ema-7
# transactionvalue-btc-wma-3
# transactionvalue-btc-wma-7
# transactionvalue-btc-std-3
# transactionvalue-btc-std-7
# transactionvalue-btc-std-14
# transactionvalue-btc-var-3
# transactionvalue-btc-var-7
# transactionvalue-btc-var-14
# transactionvalue-btc-trx-3
# transactionvalue-btc-trx-7
# transactionvalue-btc-trx-14
# transactionvalue-btc-rsi-30
# transactionvalue-btc-rsi-90
# transactionvalue-btc-roc-3
# transactionvalue-btc-roc-7
# transactionvalue-btc-roc-14
# transactionvalue-btc-roc-30
# transactionvalue-btc-roc-90
# mediantransactionvalue-btc-sma-3
# mediantransactionvalue-btc-sma-7
# mediantransactionvalue-btc-ema-3
# mediantransactionvalue-btc-wma-3
# mediantransactionvalue-btc-std-3
# mediantransactionvalue-btc-var-3
# mediantransactionvalue-btc-var-7
# mediantransactionvalue-btc-var-14
# mediantransactionvalue-btc-trx-3
# mediantransactionvalue-btc-roc-3
# mediantransactionvalue-btc-roc-7
# mediantransactionvalue-btc-roc-14
# mediantransactionvalue-btc-roc-30
# mediantransactionvalue-btc-roc-90
# fee_to_reward-btc-std-3
# fee_to_reward-btc-var-7
# fee_to_reward-btc-var-14
# fee_to_reward-btc-trx-3
# fee_to_reward-btc-rsi-30
# fee_to_reward-btc-rsi-90
# fee_to_reward-btc-roc-3
# fee_to_reward-btc-roc-7
# fee_to_reward-btc-roc-14
# fee_to_reward-btc-roc-30

# %%
X_norm1 = X_norm.drop(low_variance,axis=1)
X_norm1.head()
# Out:
#          Index  bitcoin-marketcap_raw  bitcoin-transactions_raw  \
# 2005  0.816036               0.346159                  0.474426
# 516   0.210012               0.018020                  0.067049
# 758   0.308506               0.007571                  0.188931
# 1806  0.735043               0.491160                  0.343399
# 1979  0.805454               0.376382                  0.397598
#
#       bitcoin-sentinusd_raw  bitcoin-size_raw  bitcoin-fee_to_reward_raw  \
# 2005               0.086765          0.636935                   0.027789
# 516                0.004345          0.119551                   0.000445
# 758                0.004944          0.454521                   0.008554
# 1806               0.136870          0.822494                   0.035947
# 1979               0.093334          0.578522                   0.020397
#
#       bitcoin-difficulty_raw  bitcoin-hashrate_raw  \
# 2005                0.522415              0.432689
# 516                 0.001741              0.001823
# 758                 0.003477              0.002897
# 1806                0.240339              0.240948
# 1979                0.491344              0.471009
#
#       bitcoin-activeaddresses_raw  bitcoin-tweets_raw  ...  \
# 2005                     0.459917            0.049271  ...
# 516                      0.094477            0.258269  ...
# 758                      0.160735            0.141969  ...
# 1806                     0.634809            0.096538  ...
# 1979                     0.428726            0.077969  ...
#
#       fee_to_reward-btc-var-30  fee_to_reward-btc-var-90  \
# 2005                  0.000672                  0.000582
# 516                   0.000138                  0.000030
# 758                   0.001235                  0.000348
# 1806                  0.005700                  0.966720
# 1979                  0.000958                  0.007859
#
#       fee_to_reward-btc-trx-7  fee_to_reward-btc-trx-14  \
# 2005                 0.258309                  0.352778
# 516                  0.206087                  0.426454
# 758                  0.398624                  0.597729
# 1806                 0.181253                  0.082777
# 1979                 0.334088                  0.513305
#
#       fee_to_reward-btc-trx-30  fee_to_reward-btc-trx-90  \
# 2005                  0.453815                  0.027416
# 516                   0.528053                  0.333643
# 758                   0.609648                  0.506970
# 1806                  0.053712                  0.398234
# 1979                  0.430722                  0.004182
#
#       fee_to_reward-btc-rsi-3  fee_to_reward-btc-rsi-7  \
# 2005                 0.794732                 0.587935
# 516                  0.265919                 0.359446
# 758                  0.452752                 0.440991
# 1806                 0.276594                 0.329966
# 1979                 0.276100                 0.365713
#
#       fee_to_reward-btc-rsi-14  fee_to_reward-btc-roc-90
# 2005                  0.441241                  0.095958
# 516                   0.311673                  0.085576
# 758                   0.376178                  0.190520
# 1806                  0.206518                  0.004444
# 1979                  0.330241                  0.143945
#
# [5 rows x 303 columns]

# %%
X2 = X_train.drop(columns=low_variance)

# %%
#Is there a more elegant way to reverse the normalization? Do we even need to reverse it?

# %%
X_clean1 = X_norm1*(X2.max()-X2.min())+X2.min()
X_clean1
# Out:
#        Index  bitcoin-marketcap_raw  bitcoin-transactions_raw  \
# 2005  2005.0           1.128671e+11                  248543.0
# 516    516.0           6.587252e+09                   61032.0
# 758    758.0           3.202952e+09                  117133.0
# 1806  1806.0           1.598311e+11                  188233.0
# 1979  1979.0           1.226560e+11                  213180.0
# ...      ...                    ...                       ...
# 1033  1033.0           5.686751e+09                  224225.0
# 1731  1731.0           2.632034e+11                  307486.0
# 763    763.0           3.384638e+09                  103872.0
# 835    835.0           4.096911e+09                  115417.0
# 1653  1653.0           8.010778e+10                  302941.0
#
#       bitcoin-sentinusd_raw  bitcoin-size_raw  bitcoin-fee_to_reward_raw  \
# 2005           4.057583e+09          663091.0                      1.307
# 516            2.326117e+08          186250.0                      0.201
# 758            2.604189e+08          494971.0                      0.529
# 1806           6.382913e+09          834110.0                      1.637
# 1979           4.362468e+09          609255.0                      1.008
# ...                     ...               ...                        ...
# 1033           2.645565e+09          686915.0                      1.101
# 1731           2.700042e+10          958074.0                     28.708
# 763            2.662376e+08          437712.0                      0.470
# 835            3.246532e+08          662717.0                      0.679
# 1653           7.857813e+09          902968.0                      7.721
#
#       bitcoin-difficulty_raw  bitcoin-hashrate_raw  \
# 2005            7.152633e+12          4.839568e+19
# 516             2.384467e+10          2.040071e+17
# 758             4.761056e+10          3.241311e+17
# 1806            3.290606e+12          2.694980e+19
# 1979            6.727225e+12          5.268175e+19
# ...                      ...                   ...
# 1033            1.200333e+11          9.792831e+17
# 1731            1.873105e+12          1.429391e+19
# 763             4.764340e+10          3.252408e+17
# 835             5.107637e+10          3.723519e+17
# 1653            1.123863e+12          9.281241e+18
#
#       bitcoin-activeaddresses_raw  bitcoin-tweets_raw  ...  \
# 2005                     547299.0             13536.0  ...
# 516                      150886.0             38792.0  ...
# 758                      222760.0             24738.0  ...
# 1806                     737014.0             19248.0  ...
# 1979                     513465.0             17004.0  ...
# ...                           ...                 ...  ...
# 1033                     453312.0             23530.0  ...
# 1731                     921366.0             21139.0  ...
# 763                      223246.0             21597.0  ...
# 835                      231269.0             20712.0  ...
# 1653                     689686.0             30155.0  ...
#
#       fee_to_reward-btc-var-30  fee_to_reward-btc-var-90  \
# 2005                     0.069                     0.079
# 516                      0.015                     0.006
# 758                      0.126                     0.048
# 1806                     0.578                   127.815
# 1979                     0.098                     1.041
# ...                        ...                       ...
# 1033                     0.044                     0.034
# 1731                    97.165                    78.343
# 763                      0.126                     0.047
# 835                      0.069                     0.083
# 1653                     2.227                    24.503
#
#       fee_to_reward-btc-trx-7  fee_to_reward-btc-trx-14  \
# 2005                   -0.495                    -0.854
# 516                    -1.763                    -0.004
# 758                     2.912                     1.972
# 1806                   -2.366                    -3.969
# 1979                    1.345                     0.998
# ...                       ...                       ...
# 1033                    1.528                     1.343
# 1731                    3.263                     3.842
# 763                    -2.391                     0.709
# 835                     2.402                     2.876
# 1653                   -0.311                    -1.332
#
#       fee_to_reward-btc-trx-30  fee_to_reward-btc-trx-90  \
# 2005                    -0.239                    -0.881
# 516                      0.195                    -0.222
# 758                      0.672                     0.151
# 1806                    -2.578                    -0.083
# 1979                    -0.374                    -0.931
# ...                        ...                       ...
# 1033                     0.525                     0.175
# 1731                     1.615                     0.193
# 763                      0.671                     0.171
# 835                      1.097                     0.261
# 1653                    -0.999                    -0.045
#
#       fee_to_reward-btc-rsi-3  fee_to_reward-btc-rsi-7  \
# 2005                   79.149                   60.424
# 516                    27.777                   41.830
# 758                    45.927                   48.466
# 1806                   28.814                   39.431
# 1979                   28.766                   42.340
# ...                       ...                      ...
# 1033                   37.764                   49.970
# 1731                   26.918                   48.612
# 763                    57.113                   48.881
# 835                    23.124                   40.351
# 1653                   66.504                   55.083
#
#       fee_to_reward-btc-rsi-14  fee_to_reward-btc-roc-90
# 2005                    53.725                    -8.780
# 516                     45.833                   -18.270
# 758                     49.762                    77.656
# 1806                    39.428                   -92.431
# 1979                    46.964                    35.083
# ...                        ...                       ...
# 1033                    52.417                    42.657
# 1731                    55.230                   400.810
# 763                     49.363                    14.548
# 835                     47.453                    67.509
# 1653                    50.769                   -15.502
#
# [1721 rows x 303 columns]

# %%
#
#
#PEARSON CORRELATION
#
#

# %%
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
X_clean1.corr()
# Out:
#                              Index  bitcoin-marketcap_raw  \
# Index                     1.000000               0.775478
# bitcoin-marketcap_raw     0.775478               1.000000
# bitcoin-transactions_raw  0.880950               0.636895
# bitcoin-sentinusd_raw     0.486315               0.750895
# bitcoin-size_raw          0.789430               0.498013
# ...                            ...                    ...
# fee_to_reward-btc-trx-90 -0.053397              -0.179330
# fee_to_reward-btc-rsi-3  -0.014490              -0.063568
# fee_to_reward-btc-rsi-7  -0.008871              -0.080711
# fee_to_reward-btc-rsi-14 -0.003030              -0.105691
# fee_to_reward-btc-roc-90  0.162236               0.078208
#
#                           bitcoin-transactions_raw  bitcoin-sentinusd_raw  \
# Index                                     0.880950               0.486315
# bitcoin-marketcap_raw                     0.636895               0.750895
# bitcoin-transactions_raw                  1.000000               0.552073
# bitcoin-sentinusd_raw                     0.552073               1.000000
# bitcoin-size_raw                          0.894457               0.494126
# ...                                            ...                    ...
# fee_to_reward-btc-trx-90                  0.228483               0.025189
# fee_to_reward-btc-rsi-3                   0.098062               0.025152
# fee_to_reward-btc-rsi-7                   0.134054               0.030060
# fee_to_reward-btc-rsi-14                  0.176843               0.038829
# fee_to_reward-btc-roc-90                  0.333497               0.209031
#
#                           bitcoin-size_raw  bitcoin-fee_to_reward_raw  \
# Index                             0.789430                   0.316299
# bitcoin-marketcap_raw             0.498013                   0.382279
# bitcoin-transactions_raw          0.894457                   0.513192
# bitcoin-sentinusd_raw             0.494126                   0.644351
# bitcoin-size_raw                  1.000000                   0.586367
# ...                                    ...                        ...
# fee_to_reward-btc-trx-90          0.317606                   0.350487
# fee_to_reward-btc-rsi-3           0.166719                   0.141182
# fee_to_reward-btc-rsi-7           0.188084                   0.220384
# fee_to_reward-btc-rsi-14          0.211819                   0.302223
# fee_to_reward-btc-roc-90          0.342483                   0.431418
#
#                           bitcoin-difficulty_raw  bitcoin-hashrate_raw  \
# Index                                   0.800638              0.801455
# bitcoin-marketcap_raw                   0.747027              0.757877
# bitcoin-transactions_raw                0.593378              0.598039
# bitcoin-sentinusd_raw                   0.291042              0.298904
# bitcoin-size_raw                        0.358103              0.352372
# ...                                          ...                   ...
# fee_to_reward-btc-trx-90               -0.302689             -0.289130
# fee_to_reward-btc-rsi-3                -0.029747             -0.049696
# fee_to_reward-btc-rsi-7                -0.040132             -0.063351
# fee_to_reward-btc-rsi-14               -0.059121             -0.083604
# fee_to_reward-btc-roc-90               -0.005257             -0.015902
#
#                           bitcoin-activeaddresses_raw  bitcoin-tweets_raw  \
# Index                                        0.867766            0.146409
# bitcoin-marketcap_raw                        0.733415           -0.129500
# bitcoin-transactions_raw                     0.932688            0.308515
# bitcoin-sentinusd_raw                        0.684896           -0.104741
# bitcoin-size_raw                             0.906427            0.345639
# ...                                               ...                 ...
# fee_to_reward-btc-trx-90                     0.164266            0.365742
# fee_to_reward-btc-rsi-3                      0.057836            0.057887
# fee_to_reward-btc-rsi-7                      0.067381            0.080604
# fee_to_reward-btc-rsi-14                     0.087072            0.116294
# fee_to_reward-btc-roc-90                     0.286156            0.147496
#
#                           ...  fee_to_reward-btc-var-30  \
# Index                     ...                  0.200946
# bitcoin-marketcap_raw     ...                  0.450635
# bitcoin-transactions_raw  ...                  0.281649
# bitcoin-sentinusd_raw     ...                  0.689691
# bitcoin-size_raw          ...                  0.339882
# ...                       ...                       ...
# fee_to_reward-btc-trx-90  ...                  0.122750
# fee_to_reward-btc-rsi-3   ...                 -0.084176
# fee_to_reward-btc-rsi-7   ...                 -0.088783
# fee_to_reward-btc-rsi-14  ...                 -0.048556
# fee_to_reward-btc-roc-90  ...                  0.196072
#
#                           fee_to_reward-btc-var-90  fee_to_reward-btc-trx-7  \
# Index                                     0.251865                 0.005768
# bitcoin-marketcap_raw                     0.503830                -0.063433
# bitcoin-transactions_raw                  0.193770                 0.112989
# bitcoin-sentinusd_raw                     0.531904                 0.017999
# bitcoin-size_raw                          0.317671                 0.105121
# ...                                            ...                      ...
# fee_to_reward-btc-trx-90                  0.081324                -0.011389
# fee_to_reward-btc-rsi-3                  -0.088771                 0.198824
# fee_to_reward-btc-rsi-7                  -0.155114                 0.482158
# fee_to_reward-btc-rsi-14                 -0.241688                 0.628742
# fee_to_reward-btc-roc-90                 -0.019213                 0.445245
#
#                           fee_to_reward-btc-trx-14  fee_to_reward-btc-trx-30  \
# Index                                     0.003216                 -0.015974
# bitcoin-marketcap_raw                    -0.130856                 -0.211007
# bitcoin-transactions_raw                  0.162984                  0.214915
# bitcoin-sentinusd_raw                     0.021056                  0.043308
# bitcoin-size_raw                          0.151951                  0.245328
# ...                                            ...                       ...
# fee_to_reward-btc-trx-90                  0.085248                  0.441356
# fee_to_reward-btc-rsi-3                   0.016376                 -0.028351
# fee_to_reward-btc-rsi-7                   0.229255                  0.040888
# fee_to_reward-btc-rsi-14                  0.476398                  0.226414
# fee_to_reward-btc-roc-90                  0.502748                  0.611571
#
#                           fee_to_reward-btc-trx-90  fee_to_reward-btc-rsi-3  \
# Index                                    -0.053397                -0.014490
# bitcoin-marketcap_raw                    -0.179330                -0.063568
# bitcoin-transactions_raw                  0.228483                 0.098062
# bitcoin-sentinusd_raw                     0.025189                 0.025152
# bitcoin-size_raw                          0.317606                 0.166719
# ...                                            ...                      ...
# fee_to_reward-btc-trx-90                  1.000000                 0.023061
# fee_to_reward-btc-rsi-3                   0.023061                 1.000000
# fee_to_reward-btc-rsi-7                   0.022492                 0.913147
# fee_to_reward-btc-rsi-14                  0.051635                 0.767382
# fee_to_reward-btc-roc-90                  0.389877                 0.279559
#
#                           fee_to_reward-btc-rsi-7  fee_to_reward-btc-rsi-14  \
# Index                                   -0.008871                 -0.003030
# bitcoin-marketcap_raw                   -0.080711                 -0.105691
# bitcoin-transactions_raw                 0.134054                  0.176843
# bitcoin-sentinusd_raw                    0.030060                  0.038829
# bitcoin-size_raw                         0.188084                  0.211819
# ...                                           ...                       ...
# fee_to_reward-btc-trx-90                 0.022492                  0.051635
# fee_to_reward-btc-rsi-3                  0.913147                  0.767382
# fee_to_reward-btc-rsi-7                  1.000000                  0.944526
# fee_to_reward-btc-rsi-14                 0.944526                  1.000000
# fee_to_reward-btc-roc-90                 0.417969                  0.541757
#
#                           fee_to_reward-btc-roc-90
# Index                                     0.162236
# bitcoin-marketcap_raw                     0.078208
# bitcoin-transactions_raw                  0.333497
# bitcoin-sentinusd_raw                     0.209031
# bitcoin-size_raw                          0.342483
# ...                                            ...
# fee_to_reward-btc-trx-90                  0.389877
# fee_to_reward-btc-rsi-3                   0.279559
# fee_to_reward-btc-rsi-7                   0.417969
# fee_to_reward-btc-rsi-14                  0.541757
# fee_to_reward-btc-roc-90                  1.000000
#
# [303 rows x 303 columns]

# %%
#(function syntax copied from a scikit-learn documentation)
#function selects highly correlated features and remove the first feature that is correlated with anything other feature

# %%
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
#We can discuss what a reasonable correlation level is

# %%
correlated_features = correlation(X_clean1, 0.9)
len(set(correlated_features))
# Out:
# 214

# %%
#So, thee are 214 features that are strongly correlated with other features

# %%
correlated_features
# Out:
# {'bitcoin-activeaddresses_raw',
#  'bitcoin-hashrate_raw',
#  'confirmationtime-btc-ema-14',
#  'confirmationtime-btc-ema-30',
#  'confirmationtime-btc-ema-7',
#  'confirmationtime-btc-ema-90',
#  'confirmationtime-btc-rsi-14',
#  'confirmationtime-btc-rsi-7',
#  'confirmationtime-btc-sma-14',
#  'confirmationtime-btc-sma-30',
#  'confirmationtime-btc-sma-7',
#  'confirmationtime-btc-sma-90',
#  'confirmationtime-btc-var-14',
#  'confirmationtime-btc-var-30',
#  'confirmationtime-btc-var-90',
#  'confirmationtime-btc-wma-14',
#  'confirmationtime-btc-wma-30',
#  'confirmationtime-btc-wma-7',
#  'confirmationtime-btc-wma-90',
#  'difficulty-btc-ema-14',
#  'difficulty-btc-ema-3',
#  'difficulty-btc-ema-30',
#  'difficulty-btc-ema-7',
#  'difficulty-btc-ema-90',
#  'difficulty-btc-roc-30',
#  'difficulty-btc-roc-90',
#  'difficulty-btc-rsi-14',
#  'difficulty-btc-rsi-30',
#  'difficulty-btc-rsi-7',
#  'difficulty-btc-sma-14',
#  'difficulty-btc-sma-3',
#  'difficulty-btc-sma-30',
#  'difficulty-btc-sma-7',
#  'difficulty-btc-sma-90',
#  'difficulty-btc-std-90',
#  'difficulty-btc-trx-14',
#  'difficulty-btc-trx-30',
#  'difficulty-btc-trx-90',
#  'difficulty-btc-var-14',
#  'difficulty-btc-var-30',
#  'difficulty-btc-var-90',
#  'difficulty-btc-wma-14',
#  'difficulty-btc-wma-3',
#  'difficulty-btc-wma-30',
#  'difficulty-btc-wma-7',
#  'difficulty-btc-wma-90',
#  'fee_to_reward-btc-ema-14',
#  'fee_to_reward-btc-ema-3',
#  'fee_to_reward-btc-ema-30',
#  'fee_to_reward-btc-ema-7',
#  'fee_to_reward-btc-ema-90',
#  'fee_to_reward-btc-rsi-14',
#  'fee_to_reward-btc-rsi-7',
#  'fee_to_reward-btc-sma-14',
#  'fee_to_reward-btc-sma-3',
#  'fee_to_reward-btc-sma-30',
#  'fee_to_reward-btc-sma-7',
#  'fee_to_reward-btc-std-90',
#  'fee_to_reward-btc-var-30',
#  'fee_to_reward-btc-var-90',
#  'fee_to_reward-btc-wma-14',
#  'fee_to_reward-btc-wma-3',
#  'fee_to_reward-btc-wma-30',
#  'fee_to_reward-btc-wma-7',
#  'fee_to_reward-btc-wma-90',
#  'hashrate-btc-ema-14',
#  'hashrate-btc-ema-3',
#  'hashrate-btc-ema-30',
#  'hashrate-btc-ema-7',
#  'hashrate-btc-ema-90',
#  'hashrate-btc-roc-30',
#  'hashrate-btc-roc-90',
#  'hashrate-btc-rsi-14',
#  'hashrate-btc-rsi-30',
#  'hashrate-btc-rsi-7',
#  'hashrate-btc-rsi-90',
#  'hashrate-btc-sma-14',
#  'hashrate-btc-sma-3',
#  'hashrate-btc-sma-30',
#  'hashrate-btc-sma-7',
#  'hashrate-btc-sma-90',
#  'hashrate-btc-std-14',
#  'hashrate-btc-std-30',
#  'hashrate-btc-std-7',
#  'hashrate-btc-std-90',
#  'hashrate-btc-trx-14',
#  'hashrate-btc-trx-30',
#  'hashrate-btc-trx-90',
#  'hashrate-btc-var-14',
#  'hashrate-btc-var-30',
#  'hashrate-btc-var-7',
#  'hashrate-btc-var-90',
#  'hashrate-btc-wma-14',
#  'hashrate-btc-wma-3',
#  'hashrate-btc-wma-30',
#  'hashrate-btc-wma-7',
#  'hashrate-btc-wma-90',
#  'marketcap-btc-ema-14',
#  'marketcap-btc-ema-3',
#  'marketcap-btc-ema-30',
#  'marketcap-btc-ema-7',
#  'marketcap-btc-ema-90',
#  'marketcap-btc-rsi-14',
#  'marketcap-btc-rsi-30',
#  'marketcap-btc-sma-14',
#  'marketcap-btc-sma-3',
#  'marketcap-btc-sma-30',
#  'marketcap-btc-sma-7',
#  'marketcap-btc-sma-90',
#  'marketcap-btc-std-30',
#  'marketcap-btc-std-90',
#  'marketcap-btc-var-90',
#  'marketcap-btc-wma-14',
#  'marketcap-btc-wma-3',
#  'marketcap-btc-wma-30',
#  'marketcap-btc-wma-7',
#  'marketcap-btc-wma-90',
#  'median_transaction_fee-btc-ema-14',
#  'median_transaction_fee-btc-ema-30',
#  'median_transaction_fee-btc-ema-90',
#  'median_transaction_fee-btc-rsi-14',
#  'median_transaction_fee-btc-rsi-30',
#  'median_transaction_fee-btc-sma-14',
#  'median_transaction_fee-btc-sma-30',
#  'median_transaction_fee-btc-sma-90',
#  'median_transaction_fee-btc-std-30',
#  'median_transaction_fee-btc-std-90',
#  'median_transaction_fee-btc-trx-30',
#  'median_transaction_fee-btc-trx-90',
#  'median_transaction_fee-btc-wma-30',
#  'median_transaction_fee-btc-wma-90',
#  'mediantransactionvalue-btc-ema-14',
#  'mediantransactionvalue-btc-ema-30',
#  'mediantransactionvalue-btc-ema-7',
#  'mediantransactionvalue-btc-ema-90',
#  'mediantransactionvalue-btc-rsi-14',
#  'mediantransactionvalue-btc-rsi-30',
#  'mediantransactionvalue-btc-rsi-7',
#  'mediantransactionvalue-btc-sma-14',
#  'mediantransactionvalue-btc-sma-30',
#  'mediantransactionvalue-btc-sma-90',
#  'mediantransactionvalue-btc-std-14',
#  'mediantransactionvalue-btc-std-30',
#  'mediantransactionvalue-btc-std-7',
#  'mediantransactionvalue-btc-std-90',
#  'mediantransactionvalue-btc-var-30',
#  'mediantransactionvalue-btc-var-90',
#  'mediantransactionvalue-btc-wma-14',
#  'mediantransactionvalue-btc-wma-30',
#  'mediantransactionvalue-btc-wma-7',
#  'mediantransactionvalue-btc-wma-90',
#  'mining_profitability-btc-ema-14',
#  'mining_profitability-btc-ema-30',
#  'mining_profitability-btc-ema-7',
#  'mining_profitability-btc-ema-90',
#  'mining_profitability-btc-rsi-14',
#  'mining_profitability-btc-rsi-30',
#  'mining_profitability-btc-sma-14',
#  'mining_profitability-btc-sma-30',
#  'mining_profitability-btc-sma-90',
#  'mining_profitability-btc-std-30',
#  'mining_profitability-btc-std-90',
#  'mining_profitability-btc-var-90',
#  'mining_profitability-btc-wma-14',
#  'mining_profitability-btc-wma-30',
#  'mining_profitability-btc-wma-7',
#  'mining_profitability-btc-wma-90',
#  'sentinusd-btc-ema-14',
#  'sentinusd-btc-ema-3',
#  'sentinusd-btc-ema-30',
#  'sentinusd-btc-ema-7',
#  'sentinusd-btc-ema-90',
#  'sentinusd-btc-rsi-14',
#  'sentinusd-btc-rsi-7',
#  'sentinusd-btc-sma-14',
#  'sentinusd-btc-sma-3',
#  'sentinusd-btc-sma-30',
#  'sentinusd-btc-sma-7',
#  'sentinusd-btc-std-30',
#  'sentinusd-btc-std-90',
#  'sentinusd-btc-var-30',
#  'sentinusd-btc-var-90',
#  'sentinusd-btc-wma-14',
#  'sentinusd-btc-wma-3',
#  'sentinusd-btc-wma-30',
#  'sentinusd-btc-wma-7',
#  'sentinusd-btc-wma-90',
#  'transactionfees-btc-ema-14',
#  'transactionfees-btc-ema-30',
#  'transactionfees-btc-ema-90',
#  'transactionfees-btc-rsi-14',
#  'transactionfees-btc-rsi-30',
#  'transactionfees-btc-sma-30',
#  'transactionfees-btc-sma-90',
#  'transactionfees-btc-std-30',
#  'transactionfees-btc-std-90',
#  'transactionfees-btc-wma-14',
#  'transactionfees-btc-wma-30',
#  'transactionfees-btc-wma-90',
#  'transactionvalue-btc-ema-14',
#  'transactionvalue-btc-ema-30',
#  'transactionvalue-btc-ema-90',
#  'transactionvalue-btc-rsi-14',
#  'transactionvalue-btc-rsi-7',
#  'transactionvalue-btc-sma-14',
#  'transactionvalue-btc-sma-30',
#  'transactionvalue-btc-sma-90',
#  'transactionvalue-btc-trx-30',
#  'transactionvalue-btc-trx-90',
#  'transactionvalue-btc-var-30',
#  'transactionvalue-btc-var-90',
#  'transactionvalue-btc-wma-14',
#  'transactionvalue-btc-wma-30',
#  'transactionvalue-btc-wma-90'}

# %%
X_clean2 = X_clean1.drop(correlated_features,axis=1)

# %%
X_clean2.head()
# Out:
#        Index  bitcoin-marketcap_raw  bitcoin-transactions_raw  \
# 2005  2005.0           1.128671e+11                  248543.0
# 516    516.0           6.587252e+09                   61032.0
# 758    758.0           3.202952e+09                  117133.0
# 1806  1806.0           1.598311e+11                  188233.0
# 1979  1979.0           1.226560e+11                  213180.0
#
#       bitcoin-sentinusd_raw  bitcoin-size_raw  bitcoin-fee_to_reward_raw  \
# 2005           4.057583e+09          663091.0                      1.307
# 516            2.326117e+08          186250.0                      0.201
# 758            2.604189e+08          494971.0                      0.529
# 1806           6.382913e+09          834110.0                      1.637
# 1979           4.362468e+09          609255.0                      1.008
#
#       bitcoin-difficulty_raw  bitcoin-tweets_raw  difficulty-btc-std-14  \
# 2005            7.152633e+12             13536.0           1.318379e+11
# 516             2.384467e+10             38792.0           3.218920e+09
# 758             4.761056e+10             24738.0           1.552557e+09
# 1806            3.290606e+12             19248.0           2.747457e+11
# 1979            6.727225e+12             17004.0           3.203691e+11
#
#       difficulty-btc-std-30  ...  fee_to_reward-btc-sma-90  \
# 2005           3.254955e+11  ...                     1.142
# 516            4.375309e+09  ...                     0.281
# 758            2.163317e+09  ...                     0.426
# 1806           3.143377e+11  ...                    13.943
# 1979           5.756122e+11  ...                     1.360
#
#       fee_to_reward-btc-std-7  fee_to_reward-btc-std-14  \
# 2005                    0.445                     0.392
# 516                     0.169                     0.335
# 758                     1.349                     1.010
# 1806                    0.386                     0.633
# 1979                    0.772                     0.647
#
#       fee_to_reward-btc-std-30  fee_to_reward-btc-trx-7  \
# 2005                     0.527                   -0.495
# 516                      0.241                   -1.763
# 758                      0.709                    2.912
# 1806                     1.520                   -2.366
# 1979                     0.627                    1.345
#
#       fee_to_reward-btc-trx-14  fee_to_reward-btc-trx-30  \
# 2005                    -0.854                    -0.239
# 516                     -0.004                     0.195
# 758                      1.972                     0.672
# 1806                    -3.969                    -2.578
# 1979                     0.998                    -0.374
#
#       fee_to_reward-btc-trx-90  fee_to_reward-btc-rsi-3  \
# 2005                    -0.881                   79.149
# 516                     -0.222                   27.777
# 758                      0.151                   45.927
# 1806                    -0.083                   28.814
# 1979                    -0.931                   28.766
#
#       fee_to_reward-btc-roc-90
# 2005                    -8.780
# 516                    -18.270
# 758                     77.656
# 1806                   -92.431
# 1979                    35.083
#
# [5 rows x 89 columns]

# %%
#above a datafram that has undergone two successive feature selection methods (variance & correlation)<br>
#How many variables are left?

# %%
X_clean2.shape
# Out:
# (1721, 89)

# %%
#The two feature selection methods have reduced the variable count from 439 to 89.
